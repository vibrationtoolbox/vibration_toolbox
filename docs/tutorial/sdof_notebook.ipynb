# %% [markdown]
# # Single Degree of Freedom

# %% [markdown]
# [Download This Notebook](http://vibrationtoolbox.github.io/vibration_toolbox/_downloads/sdof_notebook.ipynb)

# %%
import numpy as np
import vibration_toolbox as vtb
# %matplotlib inline

# %% [markdown]
# This notebook shows some of the functions for single degree of freedom.
#
# Some interactive functions are available (see the functions with '_i' at the end).
# To see how these interactive functions work we recommend you to download the notebook.

# %%
vtb.time_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8990cfc61e28> in <module>
# ----> 1 vtb.time_plot()
#
# AttributeError: module 'vibration_toolbox' has no attribute 'time_plot'

# %%
vtb.time_plot_i()
# Out:
# interactive(children=(FloatSlider(value=10.0, description='m', min=1.0), FloatSlider(value=1.0, description='c…

# %%
vtb.phase_plot()

# %%
vtb.phase_plot_i()
# Out:
# interactive(children=(FloatSlider(value=10.0, description='m', min=1.0, step=1.0), FloatSlider(value=1.0, desc…

# %%
r, A = vtb.steady_state_response(zs=[0.1, 0.3, 0.8], rmin=0, rmax=2)

# %%
vtb.steady_state_response_i(zs=(0, 0.5, 0.05), rmin=(0.0,1,0.1), rmax=(0,4.0,0.1))
# Out:
# interactive(children=(FloatSlider(value=0.1, description='zs', max=0.5, step=0.05), FloatSlider(value=0.0, des…

# %%
r, D, F = vtb.transmissibility(zs=[0.1, 0.3, 0.8], rmin=0, rmax=2)

# %%
vtb.transmissibility_i()
# Out:
# interactive(children=(FloatSlider(value=0.5, description='zs', max=1.0), IntSlider(value=0, description='rmin'…

# %%
r, Xn = vtb.rotating_unbalance(m=1, m0=0.5, e=0.1, zs=[0.1, 0.25, 0.707, 1], rmin=0, rmax=3.5, normalized=True)

# %%
display(vtb.sdof_interact())
