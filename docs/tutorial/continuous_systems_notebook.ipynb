# %% [markdown]
# # Continuous Systems

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import vibration_toolbox as vtb
import numpy as np

# %% [markdown]
# [Download This Notebook](http://vibrationtoolbox.github.io/vibration_toolbox/_downloads/continuous_systems_notebook.ipynb)

# %%
w, x, U = vtb.euler_beam_modes(bctype=3)
plt.plot(x, U[:, 2], '-')

# %%
fout, H = vtb.euler_beam_frf(xin=.1, xout=.3, fmax=5000, zeta=0.001)

# %%
# This interactivity doesn't work on my Mac as of Oct 12, 2017, but works on linux
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets


def ebi(xin=.4, xout=.4):
    w, v = vtb.euler_beam_frf(xin=xin, xout=xout, fmax=5000, zeta=0.001)
    print(xin)
    plt.show()

# %%
w = interactive(ebi, xin=(0.0, .4, 0.0005), xout=(0.0, .4, 0.0005))
display(w)
# Out:
# interactive(children=(FloatSlider(value=0.4, description='xin', max=0.4, step=0.0005), FloatSlider(value=0.4, description='xout', max=0.4, step=0.0005), Output()), _dom_classes=('widget-interact',))

# %%
w
# Out:
# interactive(children=(FloatSlider(value=0.4, description='xin', max=0.4, step=0.0005), FloatSlider(value=0.4, description='xout', max=0.4, step=0.0005), Output()), _dom_classes=('widget-interact',))

# %%
def f(x):
    print(x)
    return x


interact(f, x=10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-interact',))
# <function __main__.f>
